# %% [markdown]
# # **TikTok Project**
# **Course 3 - Go Beyond the Numbers: Translate Data into Insights**

# %% [markdown]
# Your TikTok data team is still in the early stages of their latest project. So far, you’ve completed a project proposal and used Python to inspect and organize the TikTok dataset.
#
# Orion Rainier, a Data Scientist at TikTok, is pleased with the work you have already completed and is requesting your assistance with some Exploratory Data Analysis (EDA) and data visualization. The management team asked to see a Python notebook showing data structuring and cleaning, as well as any matplotlib/seaborn visualizations plotted to help us understand the data. At the very least, include a graph comparing claim counts to opinion counts, as well as boxplots of the most important variables (like “video duration,” “video like count,” “video comment count,” and “video view count”) to check for outliers. Also, include a breakdown of “author ban status” counts.
#
# Additionally, the management team has recently asked all EDA to include Tableau visualizations. Tableau visualizations are particularly helpful in status reports to the client and board members. For this data, create a Tableau dashboard showing a simple claims versus opinions count, as well as stacked bar charts of claims versus opinions for variables like video view counts, video like counts, video share counts, and video download counts. Make sure it is easy to understand to someone who isn’t data savvy, and remember that the assistant director is a person with visual impairments.
#
# You also notice a follow-up email from the Data Science Lead, Willow Jaffey. Willow suggests including an executive summary of your analysis to share with teammates.
#
# A notebook was structured and prepared to help you in this project. Please complete the following questions.

# %% [markdown]
# # **Course 3 End-of-course project: Exploratory data analysis**
#
# In this activity, you will examine data provided and prepare it for analysis. You will also design a professional data visualization that tells a story, and will help data-driven decisions for business needs.
#
# Please note that the Tableau visualization activity is optional, and will not affect your completion of the course. Completing the Tableau activity will help you practice planning out and plotting a data visualization based on a specific business need. The structure of this activity is designed to emulate the proposals you will likely be assigned in your career as a data professional. Completing this activity will help prepare you for those career moments.
# <br/>
#
# **The purpose** of this project is to conduct exploratory data analysis on a provided data set. Your mission is to continue the investigation you began in C2 and perform further EDA on this data with the aim of learning more about the variables. Of particular interest is information related to what distinguishes claim videos from opinion videos.
#
# **The goal** is to explore the dataset and create visualizations.
# <br/>
# *This activity has 4 parts:*
#
# **Part 1:** Imports, links, and loading
#
# **Part 2:** Data Exploration
# *   Data cleaning
#
#
# **Part 3:** Build visualizations
#
# **Part 4:** Evaluate and share results

# %% [markdown]
# Follow the instructions and answer the question below to complete the activity. Then, you will complete an executive summary using the questions listed on the PACE Strategy Document.
#
# Be sure to complete this activity before moving on. The next course item will provide you with a completed exemplar to compare to your own work.

# %% [markdown]
# # **Visualize a story in Tableau and Python**

# %% [markdown]
# <img src="images/Pace.png" width="100" height="100" align=left>
#
# # **PACE stages**

# %% [markdown]
# Throughout these project notebooks, you'll see references to the problem-solving framework PACE. The following notebook components are labeled with the respective PACE stage: Plan, Analyze, Construct, and Execute.

# %% [markdown]
# <img src="images/Plan.png" width="100" height="100" align=left>
#
#
# ## **PACE: Plan**
#
# Consider the questions in your PACE Strategy Document and those below where applicable to craft your response:
# 1. Identify any outliers:
#
#
# *   What methods are best for identifying outliers?
# *   How do you make the decision to keep or exclude outliers from any future models?

# %% [markdown]
# ==> ENTER YOUR RESPONSE HERE

# %% [markdown]
# ### **Task 1. Imports, links, and loading**
# Go to Tableau Public
# The following link will help you complete this activity. Keep Tableau Public open as you proceed to the next steps.
#
# Link to supporting materials:
# Public Tableau: https://public.tableau.com/s/
#
# For EDA of the data, import the packages that would be most helpful, such as `pandas`, `numpy`, `matplotlib.pyplot`, and `seaborn`.

# %%
# Import packages for data manipulation
### YOUR CODE HERE ###
import pandas as pd
import numpy as np
# Import packages for data visualization
### YOUR CODE HERE ###
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# Then, load the dataset into a dataframe. Read in the data and store it as a dataframe object.
#
# **Note:** As shown in this cell, the dataset has been automatically loaded in for you. You do not need to download the .csv file, or provide more code, in order to access the dataset and proceed with this lab. Please continue with this activity by completing the following instructions.

# %%
# Load dataset into dataframe
data = pd.read_csv("../Tiktok Dataset/tiktok_dataset.csv")

# %% [markdown]
# <img src="images/Analyze.png" width="100" height="100" align=left>
#
# ## **PACE: Analyze**
#
# Consider the questions in your PACE Strategy Document and those below where applicable to complete your code.

# %% [markdown]
# ### **Task 2a: Data exploration and cleaning**
#
# The first step is to assess your data. Check the Data Source page on Tableau Public to get a sense of the size, shape and makeup of the data set.
#
# Consider functions that help you understand and structure the data.
#
# *    `.head()`
# *    `.info()`
# *    `.describe()`
# *    `.groupby()`
# *    `.sort_values()`
#
# Consider the following questions as you work:
#
# What do you do about missing data (if any)?
#
# Are there data outliers?

# %% [markdown]
# Start by discovering, using `.head()`, `.size`, and `.shape`.

# %%
# Display and examine the first few rows of the dataframe
### YOUR CODE HERE ###
data.head(10)
# Out:
#     # claim_status    video_id  video_duration_sec  \
# 0   1        claim  7017666017                  59
# 1   2        claim  4014381136                  32
# 2   3        claim  9859838091                  31
# 3   4        claim  1866847991                  25
# 4   5        claim  7105231098                  19
# 5   6        claim  8972200955                  35
# 6   7        claim  4958886992                  16
# 7   8        claim  2270982263                  41
# 8   9        claim  5235769692                  50
# 9  10        claim  4660861094                  45
#
#                             video_transcription_text verified_status  \
# 0  someone shared with me that drone deliveries a...    not verified
# 1  someone shared with me that there are more mic...    not verified
# 2  someone shared with me that american industria...    not verified
# 3  someone shared with me that the metro of st. p...    not verified
# ...

# %%
# Get the size of the data
### YOUR CODE HERE ###
data.size
# Out:
# 232584

# %%
# Get the shape of the data
### YOUR CODE HERE ###
data.shape
# Out:
# (19382, 12)

# %% [markdown]
# Get basic information about the data, using `.info()`.

# %%
# Get basic information about the data
### YOUR CODE HERE ###
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 19382 entries, 0 to 19381
# Data columns (total 12 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   #                         19382 non-null  int64
#  1   claim_status              19084 non-null  object
#  2   video_id                  19382 non-null  int64
#  3   video_duration_sec        19382 non-null  int64
#  4   video_transcription_text  19084 non-null  object
#  5   verified_status           19382 non-null  object
#  6   author_ban_status         19382 non-null  object
#  7   video_view_count          19084 non-null  float64
#  8   video_like_count          19084 non-null  float64
#  9   video_share_count         19084 non-null  float64
#  10  video_download_count      19084 non-null  float64
#  11  video_comment_count       19084 non-null  float64
# dtypes: float64(5), int64(3), object(4)
# memory usage: 1.8+ MB

# %% [markdown]
# Generate a table of descriptive statistics, using `.describe()`.

# %%
# Generate a table of descriptive statistics
### YOUR CODE HERE ###
data.describe()
# Out:
#                   #      video_id  video_duration_sec  video_view_count  \
# count  19382.000000  1.938200e+04        19382.000000      19084.000000
# mean    9691.500000  5.627454e+09           32.421732     254708.558688
# std     5595.245794  2.536440e+09           16.229967     322893.280814
# min        1.000000  1.234959e+09            5.000000         20.000000
# 25%     4846.250000  3.430417e+09           18.000000       4942.500000
# 50%     9691.500000  5.618664e+09           32.000000       9954.500000
# 75%    14536.750000  7.843960e+09           47.000000     504327.000000
# max    19382.000000  9.999873e+09           60.000000     999817.000000
#
#        video_like_count  video_share_count  video_download_count  \
# count      19084.000000       19084.000000          19084.000000
# mean       84304.636030       16735.248323           1049.429627
# std       133420.546814       32036.174350           2004.299894
# ...

# %%
#clean the missing values, they did not contain anything necessary
data = data.dropna()
data
# Out:
#            # claim_status    video_id  video_duration_sec  \
# 0          1        claim  7017666017                  59
# 1          2        claim  4014381136                  32
# 2          3        claim  9859838091                  31
# 3          4        claim  1866847991                  25
# 4          5        claim  7105231098                  19
# ...      ...          ...         ...                 ...
# 19079  19080      opinion  1492320297                  49
# 19080  19081      opinion  9841347807                  23
# 19081  19082      opinion  8024379946                  50
# 19082  19083      opinion  7425795014                   8
# 19083  19084      opinion  4094655375                  58
#
#                                 video_transcription_text verified_status  \
# 0      someone shared with me that drone deliveries a...    not verified
# 1      someone shared with me that there are more mic...    not verified
# ...

# %% [markdown]
# ### **Task 2b. Assess data types**

# %% [markdown]
# In Tableau, staying on the data source page, double check the data types of the columns in the dataset. Refer to the dimensions and measures in Tableau.

# %% [markdown]
# Review the instructions linked in the previous Activity document to create the required Tableau visualization.

# %% [markdown]
# ### **Task 2c. Select visualization type(s)**

# %% [markdown]
# Select data visualization types that will help you understand and explain the data.
#
# Now that you know which data columns you’ll use, it is time to decide which data visualization makes the most sense for EDA of the TikTok dataset. What type of data visualization(s) would be most helpful? Consider the distribution of the data.
#
# * Line graph
# * Bar chart
# * Box plot
# * Histogram
# * Heat map
# * Scatter plot
# * A geographic map

# %% [markdown]
# ==> ENTER YOUR RESPONSE HERE

# %% [markdown]
# <img src="images/Construct.png" width="100" height="100" align=left>
#
# ## **PACE: Construct**
#
# Consider the questions in your PACE Strategy Document to reflect on the Construct stage.

# %% [markdown]
# ### **Task 3. Build visualizations**
#
# Now that you have assessed your data, it’s time to plot your visualization(s).

# %% [markdown]
# #### **video_duration_sec**
#
# Create a box plot to examine the spread of values in the `video_duration_sec` column.

# %%
# Create a boxplot to visualize distribution of `video_duration_sec`
### YOUR CODE HERE ###

sns.boxplot(x = data['claim_status'], y = data['video_duration_sec'], hue = data['claim_status'])
# Out:
# <Axes: xlabel='claim_status', ylabel='video_duration_sec'>

# %% [markdown]
# Create a histogram of the values in the `video_duration_sec` column to further explore the distribution of this variable.

# %%
# Create a histogram
### YOUR CODE HERE ###
# sns.histplot(data['video_duration_sec'])

plt.figure(figsize = (11, 6))
plt.subplot(1,2,1)

sns.histplot(data['video_duration_sec'][data['claim_status'] == 'claim'], bins = 20)
plt.title('claim')

plt.subplot(1,2,2)

sns.histplot(data['video_duration_sec'][data['claim_status'] == 'opinion'], bins = 20)
plt.title('opinion')

plt.suptitle('Video Duration Count by Claim Status')
# Out:
# Text(0.5, 0.98, 'Video Duration Count by Claim Status')

# %% [markdown]
# **Question:** What do you notice about the duration and distribution of the videos?
#
# They are mostly uniform

# %% [markdown]
# #### **video_view_count**
#
# Create a box plot to examine the spread of values in the `video_view_count` column.

# %%
# Create a boxplot to visualize distribution of `video_view_count`
### YOUR CODE HERE ###
plt.figure(figsize = (11,6))
plt.subplot(1,2,1)

data['video_view_count'][data['claim_status'] == 'claim'].plot.box()

plt.title('claim')
plt.ylabel('millions')

plt.subplot(1,2,2)

data['video_view_count'][data['claim_status'] == 'opinion'].plot.box()

plt.title('opinion')
plt.ylabel('ones')

plt.suptitle('Video View Count by Claim Status')
# sns.boxplot(x = data['claim_status'], y = data['video_view_count'], hue = data['claim_status'])
# Out:
# Text(0.5, 0.98, 'Video View Count by Claim Status')

# %% [markdown]
# Create a histogram of the values in the `video_view_count` column to further explore the distribution of this variable.

# %%
# Create a histogram
### YOUR CODE HERE ###

plt.figure(figsize = (11, 6))
plt.subplot(1,2,1)

sns.histplot(data['video_view_count'][data['claim_status'] == 'claim'], bins = 30)
plt.title('claim')
plt.xlabel('video_view_count(in the millions)')

plt.subplot(1,2,2)

sns.histplot(data['video_view_count'][data['claim_status'] == 'opinion'], bins = 30)
plt.title('opinion')

plt.suptitle('Video View Count by Claim Status')
# Out:
# Text(0.5, 0.98, 'Video View Count by Claim Status')

# %% [markdown]
# **Question:** What do you notice about the distribution of this variable?
#
# Both distributions are mostly uniform, however, the claim_status seems to have a huge effect on the video_view_count

# %% [markdown]
# #### **video_like_count**
#
# Create a box plot to examine the spread of values in the `video_like_count` column.

# %%
# Create a boxplot to visualize distribution of `video_like_count`
### YOUR CODE HERE ###

plt.figure(figsize = (11,6))
plt.subplot(1,2,1)

data['video_like_count'][data['claim_status'] == 'claim'].plot.box()

plt.title('claim')

plt.subplot(1,2,2)

data['video_like_count'][data['claim_status'] == 'opinion'].plot.box()

plt.title('opinion')

plt.suptitle('Video Like Count by Claim Status')
# Out:
# Text(0.5, 0.98, 'Video Like Count by Claim Status')

# %% [markdown]
# Create a histogram of the values in the `video_like_count` column to further explore the distribution of this variable.

# %%
# Create a histogram
### YOUR CODE HERE ###



plt.figure(figsize = (11, 6))
plt.subplot(1,2,1)

sns.histplot(data['video_like_count'][data['claim_status'] == 'claim'], bins = 30)
plt.title('claim')

plt.subplot(1,2,2)

sns.histplot(data['video_like_count'][data['claim_status'] == 'opinion'], bins = 30)
plt.title('opinion')

plt.suptitle('Video Like Count by Claim Status')
# Out:
# Text(0.5, 0.98, 'Video Like Count by Claim Status')

# %% [markdown]
# **Question:** What do you notice about the distribution of this variable?
#
# The distributions are similar (both exponential) however, the video_like_count on videos with the claim_status as 'claim' is drastically more than those with claim_status 'opinion'

# %% [markdown]
# #### **video_comment_count**
#
# Create a box plot to examine the spread of values in the `video_comment_count` column.

# %%
# Create a boxplot to visualize distribution of `video_comment_count`
### YOUR CODE HERE ###

plt.figure(figsize=(11,6))
plt.subplot(1,2,1)
plt.title('claim')
data['video_comment_count'][data['claim_status'] == 'claim'].plot.box()
plt.subplot(1,2,2)
plt.title('opinion')
data['video_comment_count'][data['claim_status'] == 'opinion'].plot.box()
plt.suptitle('Video Comment Count by Claim Status')
# Out:
# Text(0.5, 0.98, 'Video Comment Count by Claim Status')

# %% [markdown]
# Create a histogram of the values in the `video_comment_count` column to further explore the distribution of this variable.

# %%
# Create a histogram
### YOUR CODE HERE ###
plt.figure(figsize = (11,6))
plt.subplot(1,2,1)
plt.title('claim')
sns.histplot(data['video_comment_count'][data['claim_status'] == 'claim'], bins = 30)
plt.subplot(1,2,2)
plt.title('opinion')
sns.histplot(data['video_comment_count'][data['claim_status'] == 'opinion'], bins = 30)
# Out:
# <Axes: title={'center': 'opinion'}, xlabel='video_comment_count', ylabel='Count'>

# %% [markdown]
# **Question:** What do you notice about the distribution of this variable?
#
# The distribution is exponential across claim and opinon videos, and again there seems to be a lot more engagement with claim videos.

# %% [markdown]
# #### **video_share_count**
#
# Create a box plot to examine the spread of values in the `video_share_count` column.

# %%
# Create a boxplot to visualize distribution of `video_share_count`
### YOUR CODE HERE ###
plt.figure(figsize=(11,6))
plt.subplot(1,2,1)
plt.title('claim')
data['video_share_count'][data['claim_status'] == 'claim'].plot.box()
plt.subplot(1,2,2)
plt.title('opinion')
data['video_share_count'][data['claim_status'] == 'opinion'].plot.box()
plt.suptitle('Video Share Count by Claim Status')
# Out:
# Text(0.5, 0.98, 'Video Share Count by Claim Status')

# %% [markdown]
# *Create* a histogram of the values in the `video_share_count` column to further explore the distribution of this variable.

# %%
# Create a histogram
### YOUR CODE HERE ###
plt.figure(figsize = (11,6))
plt.subplot(1,2,1)
plt.title('claim')
sns.histplot(data['video_share_count'][data['claim_status'] == 'claim'], bins = 30)
plt.subplot(1,2,2)
plt.title('opinion')
sns.histplot(data['video_share_count'][data['claim_status'] == 'opinion'], bins = 30)
plt.suptitle('Video Share Count by Claim Status')
# Out:
# Text(0.5, 0.98, 'Video Share Count by Claim Status')

# %% [markdown]
# **Question:** What do you notice about the distribution of this variable?
#
# The distribution is the same as video_comment_count

# %% [markdown]
# #### **video_download_count**
#
# Create a box plot to examine the spread of values in the `video_download_count` column.

# %%
# Create a boxplot to visualize distribution of `video_download_count`
### YOUR CODE HERE ###

plt.figure(figsize=(11,6))
plt.subplot(1,2,1)
plt.title('claim')
data['video_download_count'][data['claim_status'] == 'claim'].plot.box()
plt.subplot(1,2,2)
plt.title('opinion')
data['video_download_count'][data['claim_status'] == 'opinion'].plot.box()
plt.suptitle('Video Download Count by Claim Status')
# Out:
# Text(0.5, 0.98, 'Video Download Count by Claim Status')

# %% [markdown]
# Create a histogram of the values in the `video_download_count` column to further explore the distribution of this variable.

# %%
# Create a histogram
### YOUR CODE HERE ###
plt.figure(figsize = (11,6))
plt.subplot(1,2,1)
plt.title('claim')
sns.histplot(data['video_download_count'][data['claim_status'] == 'claim'], bins = 30)
plt.subplot(1,2,2)
plt.title('opinion')
sns.histplot(data['video_download_count'][data['claim_status'] == 'opinion'], bins = 30)
plt.suptitle('Video Download Count by Claim Status')
# Out:
# Text(0.5, 0.98, 'Video Download Count by Claim Status')

# %% [markdown]
# **Question:** What do you notice about the distribution of this variable?
#
# The distribution of this variable seems to be the same as video_comment_count and video_download_count.

# %% [markdown]
# #### **Claim status by verification status**
#
# Now, create a histogram with four bars: one for each combination of claim status and verification status.

# %%
# Create a histogram
### YOUR CODE HERE ###

a = pd.DataFrame()
a['claim and verified status'] = data['claim_status'] + ' ' + data['verified_status']



sns.histplot(data = a['claim and verified status'])
plt.xticks(rotation = 45, horizontalalignment = "right")


data.info()
# g = sns.histplot(data = b, x = [i for i in range(len(b))], y = b, bins = 4, discrete=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 19084 entries, 0 to 19083
# Data columns (total 12 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   #                         19084 non-null  int64
#  1   claim_status              19084 non-null  object
#  2   video_id                  19084 non-null  int64
#  3   video_duration_sec        19084 non-null  int64
#  4   video_transcription_text  19084 non-null  object
#  5   verified_status           19084 non-null  object
#  6   author_ban_status         19084 non-null  object
#  7   video_view_count          19084 non-null  float64
#  8   video_like_count          19084 non-null  float64
#  9   video_share_count         19084 non-null  float64
#  10  video_download_count      19084 non-null  float64
#  11  video_comment_count       19084 non-null  float64
# dtypes: float64(5), int64(3), object(4)
# memory usage: 1.9+ MB

# %% [markdown]
# **Question:** What do you notice about the number of verified users compared to unverified? And how does that affect their likelihood to post opinions?
#
# The proportion of verifeid to unverified for claim is much smaller than that of opinion

# %% [markdown]
# #### **Claim status by author ban status**
#
# The previous course used a `groupby()` statement to examine the count of each claim status for each author ban status. Now, use a histogram to communicate the same information.

# %%
# Create a histogram
### YOUR CODE HERE ###

a['claim and author ban status'] = data['claim_status'] + ' ' + data['author_ban_status']
sns.histplot(data = a['claim and author ban status'])
plt.xticks(rotation = 45, horizontalalignment = "right")
# Out:
# ([0, 1, 2, 3, 4, 5],
#  [Text(0, 0, 'claim under review'),
#   Text(1, 0, 'claim active'),
#   Text(2, 0, 'claim banned'),
#   Text(3, 0, 'opinion active'),
#   Text(4, 0, 'opinion banned'),
#   Text(5, 0, 'opinion under review')])

# %%
#Print percentages / proportions
#let suspicious = banned or under review

stats = data.groupby(['claim_status', 'author_ban_status'])['#'].count()
claim_suspicious = data['#'][(data['claim_status'] == 'claim') & ((data['author_ban_status'] == 'under review') | (data['author_ban_status'] == 'banned'))].count()
claim_not_suspicious = data['#'][(data['claim_status'] == 'claim') & (data['author_ban_status'] == 'active')].count()
print('claim ratio: ' + str(claim_suspicious/claim_not_suspicious))

opinion_suspicious = data['#'][(data['claim_status'] == 'opinion') & ((data['author_ban_status'] == 'under review') | (data['author_ban_status'] == 'banned'))].count()
opinion_not_suspicious = data['#'][(data['claim_status'] == 'opinion') & (data['author_ban_status'] == 'active')].count()
print('opinion ratio: ' + str(opinion_suspicious/opinion_not_suspicious))
# Out:
# claim ratio: 0.4632957660676211
# opinion ratio: 0.0747419757287059

# %% [markdown]
# **Question:** What do you notice about the number of active authors compared to banned authors for both claims and opinions?
#
# The proportion of banned and under review authors to unbanned that produce "claim" content is greater than the proportion for "opinion" content

# %% [markdown]
# #### **Median view counts by ban status**
#
# Create a bar plot with three bars: one for each author ban status. The height of each bar should correspond with the median number of views for all videos with that author ban status.

# %%
# Create a bar plot
a = data.groupby('author_ban_status')['video_view_count'].median()
sns.barplot(x = a.index, y = a)
# Out:
# <Axes: xlabel='author_ban_status', ylabel='video_view_count'>

# %% [markdown]
# **Question:** What do you notice about the median view counts for non-active authors compared to that of active authors? Based on that insight, what variable might be a good indicator of claim status?
#
# banned authors and those under review have much higher view counts

# %%
# Calculate the median view count for claim status.
### YOUR CODE HERE ###

b = data.groupby('claim_status')['video_view_count'].median()

# %% [markdown]
# #### **Total views by claim status**
#
# Create a pie graph that depicts the proportions of total views for claim videos and total views for opinion videos.

# %%
# Create a pie graph
### YOUR CODE HERE ###

plt.pie(data.groupby('claim_status')['video_view_count'].sum(), labels = ['claim', 'opinon'])
# Out:
# ([<matplotlib.patches.Wedge at 0x1840878d120>,
# ...
#  [Text(-1.0994932510793276, 0.033385488329672315, 'claim'),
#   Text(1.0994932496141194, -0.033385536583728705, 'opinon')])

# %% [markdown]
# **Question:** What do you notice about the overall view count for claim status?
#
# The view count is largely monopolized by the "claim" content

# %% [markdown]
# ### **Task 4. Determine outliers**
#
# When building predictive models, the presence of outliers can be problematic. For example, if you were trying to predict the view count of a particular video, videos with extremely high view counts might introduce bias to a model. Also, some outliers might indicate problems with how data was captured or recorded.
#
# The ultimate objective of the TikTok project is to build a model that predicts whether a video is a claim or opinion. The analysis you've performed indicates that a video's engagement level is strongly correlated with its claim status. There's no reason to believe that any of the values in the TikTok data are erroneously captured, and they align with expectation of how social media works: a very small proportion of videos get super high engagement levels. That's the nature of viral content.
#
# Nonetheless, it's good practice to get a sense of just how many of your data points could be considered outliers. The definition of an outlier can change based on the details of your project, and it helps to have domain expertise to decide a threshold. You've learned that a common way to determine outliers in a normal distribution is to calculate the interquartile range (IQR) and set a threshold that is 1.5 * IQR above the 3rd quartile.
#
# In this TikTok dataset, the values for the count variables are not normally distributed. They are heavily skewed to the right. One way of modifying the outlier threshold is by calculating the **median** value for each variable and then adding 1.5 * IQR. This results in a threshold that is, in this case, much lower than it would be if you used the 3rd quartile.
#
# Write a for loop that iterates over the column names of each count variable. For each iteration:
# 1. Calculate the IQR of the column
# 2. Calculate the median of the column
# 3. Calculate the outlier threshold (median + 1.5 * IQR)
# 4. Calculate the numer of videos with a count in that column that exceeds the outlier threshold
# 5. Print "Number of outliers, {column name}: {outlier count}"
#
# ```
# Example:
# Number of outliers, video_view_count: ___
# Number of outliers, video_like_count: ___
# Number of outliers, video_share_count: ___
# Number of outliers, video_download_count: ___
# Number of outliers, video_comment_count: ___
# ```

# %%
### YOUR CODE HERE ###


for i in data.columns:
    if 'count' in i:
        iqr = data[i].quantile(.75) - data[i].quantile(.25)
        med = data[i].median()
        upThresh = med + 1.5 * iqr
        lowThresh = med - 1.5 * iqr
        print(f'Number of outliers, {i}: {data[i][(data[i] > upThresh) | (data[i] < lowThresh)].count()}')
# Out:
# Number of outliers, video_view_count: 2343
# Number of outliers, video_like_count: 3468
# Number of outliers, video_share_count: 3732
# Number of outliers, video_download_count: 3733
# Number of outliers, video_comment_count: 3882

# %% [markdown]
# #### **Scatterplot**

# %%
# Create a scatterplot of `video_like_count` versus `video_comment_count` according to 'claim_status'
### YOUR CODE HERE ###




# b = data.groupby(['claim_status'])['video_view_count', 'video_comment_count'].count()
sns.scatterplot(x = data['video_like_count'], y = data['video_comment_count'], hue = data['claim_status'])
# Out:
# <Axes: xlabel='video_like_count', ylabel='video_comment_count'>

# %%
# Create a scatterplot of `video_like_count` versus `video_comment_count` for opinions only
### YOUR CODE HERE ###

sns.scatterplot(x = data['video_like_count'][data['claim_status'] == 'opinion'], y = data['video_comment_count'][data['claim_status'] == 'opinion'], color = 'orange')
# Out:
# <Axes: xlabel='video_like_count', ylabel='video_comment_count'>

# %% [markdown]
# You can do a scatterplot in Tableau Public as well, which can be easier to manipulate and present. If you'd like step by step instructions, you can review the instructions linked in the previous Activity page.

# %% [markdown]
# <img src="images/Execute.png" width="100" height="100" align=left>
#
# ## **PACE: Execute**
#
# Consider the questions in your PACE Strategy Document to reflect on the Execute stage.

# %% [markdown]
# ### **Task 5a. Results and evaluation**
#
# Having built visualizations in Tableau and in Python, what have you learned about the dataset? What other questions have your visualizations uncovered that you should pursue?
#
# ***Pro tip:*** Put yourself in your client's perspective, what would they want to know?
#
# Use the following code cells to pursue any additional EDA. Also use the space to make sure your visualizations are clean, easily understandable, and accessible.
#
# ***Ask yourself:*** Did you consider color, contrast, emphasis, and labeling?

# %% [markdown]
# ==> ENTER YOUR RESPONSE HERE
#
# I have learned .... The different types of visualizations in Seaborn and Matplotlib and their nuances.
#
# My other questions are ....
#
# My client would likely want to know ... The statistically significant statistics relating "opinion" content to "claim" content.

# %% [markdown]
# ### **Task 5b. Conclusion**
# *Make it professional and presentable*
#
# You have visualized the data you need to share with the director now. Remember, the goal of a data visualization is for an audience member to glean the information on the chart in mere seconds.
#
# *Questions to ask yourself for reflection:*
# Why is it important to conduct Exploratory Data Analysis? What other visuals could you create?

# %% [markdown]
# EDA is important because ...
#
# It establishes the relationships between variables and involves the data cleaning process which is vital to ensuring the data is portrayed in a efficient manner.
#
# Visualizations helped me understand ..
#
# Visualizations can portray the data in a way where a trend can be emphasized and simplified, however care should be taken to avoid bias.

# %% [markdown]
# You’ve now completed a professional data visualization according to a business need. Well done! Be sure to save your work as a reference for later work in Tableau.

# %% [markdown]
# **Congratulations!** You've completed this lab. However, you may not notice a green check mark next to this item on Coursera's platform. Please continue your progress regardless of the check mark. Just click on the "save" icon at the top of this notebook to ensure your work has been logged.
